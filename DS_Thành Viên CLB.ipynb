# %%
import pandas as pd

# %%
a= pd.read_csv('RadioHUET.csv', sep=';')
del a['Identification']
a
# Out:
#       Date submitted                   Name  \
# 0  05:07, 02/10/2021           Bùi Minh Tài
# 1  17:29, 01/10/2021       Nguyễn Văn Hoàng
# 2  15:49, 01/10/2021     Trần Đoàn Ngọc Duy
# 3  14:24, 21/09/2021        Dạ em tên Khánh
# 4  04:16, 24/08/2021    Hoàng Nữ Thu Phương
# 5  01:52, 18/08/2021  Nguyễn Nhật Đạt Thành
# 6  03:59, 14/08/2021            Ngô Ngọc Hà
#
#                                             Facebook  \
# 0  https://www.facebook.com/profile.php?id=100036...
# 1  https://www.facebook.com/profile.php?id=100038...
# 2                 https://www.facebook.com/yhss.duy/
# 3              https://www.facebook.com/kaere.K.1203
# 4          Https://www.facebook.com/hoangnuthuphuong
# 5  https://www.facebook.com/profile.php?id=100012...
# 6               https://www.facebook.com/minango2003
#
#                                         Tính cách  \
# 0                                          Bí mật
# 1                                     Ham học hỏi
# ...

# %%
a
# Out:
#       Date submitted                   Name  \
# 0  05:07, 02/10/2021           Bùi Minh Tài
# 1  17:29, 01/10/2021       Nguyễn Văn Hoàng
# 2  15:49, 01/10/2021     Trần Đoàn Ngọc Duy
# 3  14:24, 21/09/2021        Dạ em tên Khánh
# 4  04:16, 24/08/2021    Hoàng Nữ Thu Phương
# 5  01:52, 18/08/2021  Nguyễn Nhật Đạt Thành
# 6  03:59, 14/08/2021            Ngô Ngọc Hà
#
#                                             Facebook  \
# 0  https://www.facebook.com/profile.php?id=100036...
# 1  https://www.facebook.com/profile.php?id=100038...
# 2                 https://www.facebook.com/yhss.duy/
# 3              https://www.facebook.com/kaere.K.1203
# 4          Https://www.facebook.com/hoangnuthuphuong
# 5  https://www.facebook.com/profile.php?id=100012...
# 6               https://www.facebook.com/minango2003
#
#                                         Tính cách  \
# 0                                          Bí mật
# 1                                     Ham học hỏi
# ...
